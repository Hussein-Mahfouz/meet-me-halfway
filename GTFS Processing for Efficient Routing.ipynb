# %%
import pandas as pd
from shapely.geometry import Point, MultiPoint
import osmnx as ox
from shapely import Polygon
import geojson
from geopandas import GeoDataFrame
import networkx as nx
import pickle

# %%
class stop_object:
    def __init__ (self, routes, connected_stops, all_walk_times):
        self.routes = routes
        self.connected_stops = connected_stops
        self.all_walk_times = all_walk_times

# Route object

#For each stop a route object
# Departure time, sequence, tripID

class stop_route:
    def __init__ (self, departures):
        self.departures = departures

# %%
gtfs_data = 'Input Data/study_area_gtfs_bus/'

# gtfs_calendar = pd.read_csv(gtfs_data+'calendar.txt', sep=",", header=0)
# gtfs_calendar_dates = pd.read_csv(gtfs_data+'calendar_dates.txt', sep=",", header=0)
# gtfs_routes = pd.read_csv(gtfs_data+'routes.txt', sep=",", header=0)
gtfs_stop_times = pd.read_csv(gtfs_data+'stop_times.txt', sep=",", header=0, dtype={3:str,5:str})
gtfs_stops = pd.read_csv(gtfs_data+'stops.txt', sep=",", header=0)
gtfs_trips = pd.read_csv(gtfs_data+'trips.txt', sep=",", header=0)

# %%
bounding_box = tuple([-1.647263,53.755816,-1.426849,53.847666])

point1 = (-1.647263,53.755816)  # Replace longitude1 and latitude1 with your actual values
point2 = (-1.426849,53.847666)  # Replace longitude2 and latitude2 with your actual values

# Create the bounding box polygon
bbox_polygon = Polygon([
    (point1[0], point1[1]),
    (point2[0], point1[1]),
    (point2[0], point2[1]),
    (point1[0], point2[1]),
    (point1[0], point1[1])
])

# Convert the polygon to GeoJSON format
geojson_polygon = geojson.Feature(geometry=bbox_polygon, properties={})

# Output the GeoJSON to a file
with open("Outputs/bounding_box.geojson", "w") as f:
    geojson.dump(geojson_polygon, f)

# %%
stop_geoms = {}

for i,r in gtfs_stops.iterrows():
    stop_geom = Point([r['stop_lon'],r['stop_lat']])
    if bbox_polygon.contains(stop_geom):
        stop_geoms[r['stop_id']] = Point([r['stop_lon'],r['stop_lat']])

# %%
multi_point = MultiPoint(list(stop_geoms.values()))

# Convert the MultiPoint to GeoJSON format
geojson_multipoint = geojson.Feature(geometry=multi_point, properties={})

# Output the GeoJSON to a file
with open("Outputs/stops_in_study.geojson", "w") as f:
    geojson.dump(geojson_multipoint, f)
    
G = ox.graph_from_bbox(53.847666,53.755816, -1.426849, -1.647263, network_type = 'walk')

edges = ox.graph_to_gdfs(G,nodes = False)

# Output to file
edge_attributes_gdf = GeoDataFrame(edges[['geometry']], crs="EPSG:4326", geometry=edges['geometry'])
edge_attributes_gdf.to_file("Outputs/network.json", driver="GeoJSON")

# %%
stop_to_node = {}
for stop in list(stop_geoms.keys()):
    next_stop = stop_geoms[stop]
    stop_to_node[stop] = ox.nearest_nodes(G, next_stop.x, next_stop.y)

# %%
mph = 2.98
mps = mph * 0.44704

stops_in_area = list(stop_to_node.keys())
stop_to_stop_walk_time = {}
num_stops = len(stops_in_area)

count_stops_processed = 0

for u in stops_in_area:
    u_node = [stop_to_node[u]]
    length, path = nx.multi_source_dijkstra(G, u_node,  weight='length')

    stop_to_stop_walk_time[u] = {}

    v = stops_in_area[0]

    for v in stops_in_area:
        stop_to_stop_walk_time[u][v] = (length[stop_to_node[v]] / mps)
    
    count_stops_processed += 1
    
    print('-------------------------------------')
    print('Overall Progress {} of {}'.format(count_stops_processed,num_stops))
    print('-------------------------------------')
# Out:
# -------------------------------------
# Overall Progress 1 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress
of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 357 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 358 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 359 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 360 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 361 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 362 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 363 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 364 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 365 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 366 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 367 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 368 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 369 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 370 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 371 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 372 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 373 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 374 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 375 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 376 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 377 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 378 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 379 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 380 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 381 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 382 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 383 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 384 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 385 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 386 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 387 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 388 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 389 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 390 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 391 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 392 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 393 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 394 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 395 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 396 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 397 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 398 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 399 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 400 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 401 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 402 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 403 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 404 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 405 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 406 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 407 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 408 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 409 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 410 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 411 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 412 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 413 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 414 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 415 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 416 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 417 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 418 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 419 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 420 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 421 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 422 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 423 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 424 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 425 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 426 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 427 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 428 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 429 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 430 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 431 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 432 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 433 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 434 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 435 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 436 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 437 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 438 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 439 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 440 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 441 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 442 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 443 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 444 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 445 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 446 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 447 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 448 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 449 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 450 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 451 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 452 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 453 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 454 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 455 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 456 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 457 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 458 of 2095
# -------------------------------------
# ...
# Overall Progress 1945 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1946 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1947 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1948 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1949 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1950 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1951 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1952 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1953 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1954 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1955 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1956 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1957 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1958 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1959 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1960 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1961 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1962 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1963 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1964 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1965 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1966 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1967 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1968 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1969 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1970 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1971 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1972 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1973 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1974 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1975 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1976 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1977 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1978 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1979 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1980 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1981 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1982 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1983 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1984 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1985 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1986 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1987 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1988 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1989 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1990 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1991 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1992 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1993 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1994 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1995 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1996 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1997 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1998 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 1999 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2000 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2001 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2002 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2003 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2004 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2005 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2006 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2007 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2008 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2009 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2010 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2011 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2012 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2013 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2014 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2015 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2016 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2017 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2018 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2019 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2020 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2021 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2022 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2023 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2024 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2025 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2026 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2027 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2028 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2029 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2030 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2031 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2032 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2033 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2034 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2035 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2036 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2037 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2038 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2039 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2040 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2041 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2042 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2043 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2044 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2045 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2046 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2047 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2048 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2049 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2050 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2051 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2052 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2053 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2054 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2055 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2056 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2057 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2058 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2059 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2060 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2061 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2062 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2063 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2064 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2065 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2066 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2067 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2068 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2069 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2070 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2071 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2072 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2073 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2074 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2075 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2076 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2077 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2078 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2079 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2080 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2081 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2082 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2083 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2084 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2085 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2086 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2087 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2088 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2089 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2090 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2091 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2092 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2093 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2094 of 2095
# -------------------------------------
# -------------------------------------
# Overall Progress 2095 of 2095
# -------------------------------------

# %%
acceptable_walk_time = 450
start_index = 0
end_index = 2
stop_classes = {}
num_processed = 0

for stop_id in stops_in_area:
    filtered_stops = {stop: time for stop, time in stop_to_stop_walk_time[stop_id].items() if time < acceptable_walk_time}
    connecting_stops = list(filtered_stops.keys())
    stop_time = gtfs_stop_times[gtfs_stop_times['stop_id'].isin(connecting_stops)]
    stop_time = stop_time.merge(gtfs_trips[['trip_id','route_id']],left_on='trip_id',right_on='trip_id')

    route_dict = {}
    for route in list(set(list(stop_time['route_id']))):
        route_stop_times = stop_time[stop_time['route_id'] == route]
        route_stop_times = route_stop_times.drop_duplicates(subset=['arrival_time'])
        # Restrict to under 23 hours
        route_stop_times['hour'] = route_stop_times['arrival_time'].apply(lambda x: x[start_index:end_index]).astype(int)
        route_stop_times = route_stop_times[route_stop_times['hour'] < 23]
        
        route_dict[route] = stop_route(route_stop_times.set_index('arrival_time')[['trip_id','route_id','stop_id']].to_dict('index'))
        
    stop_classes[stop_id] = stop_object(route_dict, connecting_stops, stop_to_stop_walk_time[stop_id])

    num_processed += 1
    if num_processed % 10 == 0:
        print('Progress : {}'.format((num_processed / num_stops)* 100))

f = open('Outputs/stops_dict.txt', 'wb')
pickle.dump(stop_classes,f)
f.close()
# Out:
# Progress : 0.47732696897374705
# Progress : 0.9546539379474941
# Progress : 1.431980906921241
# Progress : 1.9093078758949882
# Progress : 2.386634844868735
# Progress : 2.863961813842482
# Progress : 3.341288782816229
# Progress : 3.8186157517899764
# Progress : 4.295942720763723
# Progress : 4.77326968973747
# Progress : 5.250596658711217
# Progress : 5.727923627684964
# Progress : 6.205250596658711
# Progress : 6.682577565632458
# Progress : 7.159904534606206
# Progress : 7.637231503579953
# Progress : 8.1145584725537
# Progress : 8.591885441527445
# Progress : 9.069212410501192
# Progress : 9.54653937947494
# Progress : 10.023866348448687
# Progress : 10.501193317422434
# Progress : 10.978520286396181
# Progress : 11.455847255369928
# Progress : 11.933174224343675
# Progress : 12.410501193317423
# Progress : 12.887828162291171
# Progress : 13.365155131264917
# Progress : 13.842482100238662
# Progress : 14.319809069212411
# Progress : 14.797136038186157
# Progress : 15.274463007159905
# Progress : 15.75178997613365
# Progress : 16.2291169451074
# Progress : 16.706443914081145
# Progress : 17.18377088305489
# Progress : 17.66109785202864
# Progress : 18.138424821002385
# Progress : 18.615751789976134
# Progress : 19.09307875894988
# Progress : 19.570405727923628
# Progress : 20.047732696897373
# Progress : 20.52505966587112
# Progress : 21.002386634844868
# Progress : 21.479713603818613
# Progress : 21.957040572792362
# Progress : 22.434367541766107
# Progress : 22.911694510739856
# Progress : 23.389021479713605
# Progress : 23.86634844868735
# Progress : 24.3436754176611
# Progress : 24.821002386634845
# Progress : 25.29832935560859
# Progress : 25.775656324582343
# Progress : 26.25298329355609
# Progress : 26.730310262529834
# Progress : 27.20763723150358
# Progress : 27.684964200477324
# Progress : 28.162291169451077
# Progress : 28.639618138424822
# Progress : 29.116945107398568
# Progress : 29.594272076372313
# Progress : 30.071599045346066
# Progress : 30.54892601431981
# Progress : 31.026252983293556
# Progress : 31.5035799522673
# Progress : 31.980906921241047
# Progress : 32.4582338902148
# Progress : 32.93556085918855
# Progress : 33.41288782816229
# Progress : 33.89021479713604
# Progress : 34.36754176610978
# Progress : 34.84486873508354
# Progress : 35.32219570405728
# Progress : 35.79952267303103
# Progress : 36.27684964200477
# Progress : 36.754176610978526
# Progress : 37.23150357995227
# Progress : 37.70883054892602
# Progress : 38.18615751789976
# Progress : 38.66348448687351
# Progress : 39.140811455847256
# Progress : 39.618138424821005
# Progress : 40.09546539379475
# Progress : 40.572792362768496
# Progress : 41.05011933174224
# Progress : 41.527446300715994
# Progress : 42.004773269689736
# Progress : 42.482100238663485
# Progress : 42.959427207637226
# Progress : 43.43675417661098
# Progress : 43.914081145584724
# Progress : 44.39140811455847
# Progress : 44.868735083532215
# Progress : 45.346062052505964
# Progress : 45.82338902147971
# Progress : 46.30071599045346
# Progress : 46.77804295942721
